# %%
import pandas as pd

# %%
pd.read_excel(r'C:\Users\Sujit\Desktop\Book1.xlsx')
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2
# 0       name      data0   passwprd
# 1      Sujit          5          5
# 2      sujit          5          5
# 3      sujit          5          5
# 4      sujit          5          5
# 5      sujit          5          5
# 6      sujit          5          5

# %%
pd.read_excel(r'C:\Users\Sujit\Desktop\Sujit.xlsx')
# Out:
#         Sr.no           Name of Student Name Of Organization  \
# 0           1  Sujit Sambhajirao Kendre   IIM Krishi Manthan
# 1           2        Anil laxman chavan   IIM Krishi Manthan
# 2           3              mahesh Tathe   IIM Krishi Manthan
# 3  Big Bazaar                       NaN                  NaN
# 4           1         Ram Vijay Tangade           Big Bazaar
# 5           2  Sujit Sambhajirao Kendre           Big Bazaar
# 6           3        Anil Laxman Chavan           Big Bazaar
# 7           4              Mahesh Tathe           Big Bazaar
# 8           5            shreyash Dayma           Big Bazaar
#
#   With Permission or Without Permission            Dates Of Absent  \
# 0                       With Permission  28/12/2019 To 29-12//2019
# 1                       With Permission  28/12/2019 To 29-12//2019
# 2                       With Permission  28/12/2019 To 29-12//2019
# 3                                   NaN                        NaN
# ...
